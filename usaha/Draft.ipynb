# %%
import pandas as pd
import matplotlib.pyplot as plt

import openpyxl
from openpyxl import load_workbook

from kmodes.kmodes import KModes

# %%
wb = load_workbook('dataset_usaha.xlsx');
sheet = wb['main']

# %%
data = []

for row in sheet.iter_rows(values_only=True):
    data.append(row)

# Convert the list of data into a DataFrame
df = pd.DataFrame(data)

# %%
df
# Out:
#          0              1                2                             3   \
# 0       No.            Nib  Npwp Perusahaan               Nama Perusahaan
# 1         1  9120018051443  906904768824000   APOTEK TOKIN INTI SEJAHTERA
# 2         2  9120200932569  141501502824000                   INDRA MOTOR
# 3         3  9120200932569  141501502824000                   INDRA MOTOR
# 4         4  8120115030514  857446868824000  JOBUBU SUKSESRAYA DISTRIBUSI
# ...     ...            ...              ...                           ...
# 5737  5.737  0404230015782  751442286824000        NUSANTARA JAYA MANDIRI
# 5738  5.738  0404230015782  751442286824000        NUSANTARA JAYA MANDIRI
# 5739  5.739  0404230015782  751442286824000        NUSANTARA JAYA MANDIRI
# 5740  5.740  0404230045403  147243976824000             PATRIS INDRA PAAT
# 5741  5.741  0404230045403  147243976824000             PATRIS INDRA PAAT
#
#                                  4   \
# 0     Uraian Status Penanaman Modal
# ...

# %%
df.columns = df.iloc[0]

# %%
df.dtypes
# Out:
# 0
# No.                              object
# Nib                              object
# Npwp Perusahaan                  object
# Nama Perusahaan                  object
# Uraian Status Penanaman Modal    object
# Uraian Jenis Perusahaan          object
# Uraian Risiko Proyek             object
# nama_proyek                      object
# Uraian Skala Usaha               object
# Alamat Usaha                     object
# kecamatan_usaha                  object
# kelurahan_usaha                  object
# Kbli                             object
# Judul Kbli                       object
# Nama User                        object
# Nomor Identitas User             object
# Nomor Telp                       object
# dtype: object

# %%
df = df.drop(0)

# %%
df = df.drop('No.', axis=1)

# %%
df.columns
# Out:
# Index(['Nib', 'Npwp Perusahaan', 'Nama Perusahaan',
#        'Uraian Status Penanaman Modal', 'Uraian Jenis Perusahaan',
#        'Uraian Risiko Proyek', 'nama_proyek', 'Uraian Skala Usaha',
#        'Alamat Usaha', 'kecamatan_usaha', 'kelurahan_usaha', 'Kbli',
#        'Judul Kbli', 'Nama User', 'Nomor Identitas User', 'Nomor Telp'],
#       dtype='object', name=0)

# %%
df_target_cluster =  df[['Uraian Jenis Perusahaan', 'Uraian Risiko Proyek', 'Uraian Skala Usaha', 'Kbli']]

# %%
df_target_cluster
# Out:
# 0                               Uraian Jenis Perusahaan Uraian Risiko Proyek  \
# 1                                            Perorangan               Tinggi
# 2                                            Perorangan      Menengah Rendah
# 3                                            Perorangan               Rendah
# 4                               Perseroan Terbatas (PT)               Tinggi
# 5                               Perseroan Terbatas (PT)               Rendah
# ...                                                 ...                  ...
# 5737  Persekutuan Komanditer (CV / Commanditaire Ven...               Rendah
# 5738  Persekutuan Komanditer (CV / Commanditaire Ven...               Tinggi
# 5739  Persekutuan Komanditer (CV / Commanditaire Ven...               Tinggi
# 5740                                         Perorangan               Rendah
# 5741                                         Perorangan               Rendah
#
# 0    Uraian Skala Usaha   Kbli
# ...

# %% [raw]
# df_target_cluster[df_target_cluster['Uraian Risiko Proyek'] == 'Tinggi'].head(20)

# %% [raw]
# df_target_cluster[df_target_cluster['Uraian Jenis Perusahaan'] == 'Tinggi']

# %% [raw]
# df['Uraian Jenis Perusahaan'].describe()

# %% [raw]
# df['Uraian Jenis Perusahaan'].unique()

# %% [raw]
# df_target_cluster[df_target_cluster['Uraian Jenis Perusahaan'] == 'Perorangan'].describe()

# %%
df_target_cluster
# Out:
# 0                               Uraian Jenis Perusahaan Uraian Risiko Proyek  \
# 1                                            Perorangan               Tinggi
# 2                                            Perorangan      Menengah Rendah
# 3                                            Perorangan               Rendah
# 4                               Perseroan Terbatas (PT)               Tinggi
# 5                               Perseroan Terbatas (PT)               Rendah
# ...                                                 ...                  ...
# 5737  Persekutuan Komanditer (CV / Commanditaire Ven...               Rendah
# 5738  Persekutuan Komanditer (CV / Commanditaire Ven...               Tinggi
# 5739  Persekutuan Komanditer (CV / Commanditaire Ven...               Tinggi
# 5740                                         Perorangan               Rendah
# 5741                                         Perorangan               Rendah
#
# 0    Uraian Skala Usaha   Kbli
# ...

# %%
kmode = KModes(n_clusters=num_clusters, init = "random", n_init = 5, verbose=1)
kmode.fit_predict(df_target_cluster)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2896\2834821145.py in <module>
#       1 kmode = KModes(n_clusters=num_clusters, init = "random", n_init = 5, verbose=1)
# ----> 2 kmode.fit_predict(df_target_cluster)
#
# ~\anaconda3\lib\site-packages\kmodes\kmodes.py in fit_predict(self, X, y, **kwargs)
#     152         predict(X).
#     153         """
# --> 154         return self.fit(X, **kwargs).predict(X, **kwargs)
#     155
#     156     def predict(self, X, **kwargs):
#
# ~\anaconda3\lib\site-packages\kmodes\kmodes.py in fit(self, X, y, sample_weight, **kwargs)
#     132
#     133         self._enc_cluster_centroids, self._enc_map, self.labels_, self.cost_, \
# --> 134         self.n_iter_, self.epoch_costs_ = k_modes(
#     135             X,
#     136             self.n_clusters,
#
# ...

# %%
cost = []
K = range(1,5)
for num_clusters in list(K):
    kmode = KModes(n_clusters=num_clusters, init = "random", n_init = 5, verbose=1)
    kmode.fit_predict(df_target_cluster)
    cost.append(kmode.cost_)
    
plt.plot(K, cost, 'bx-')
plt.xlabel('No. of clusters')
plt.ylabel('Cost')
plt.title('Elbow Method For Optimal k')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2896\989705841.py in <module>
#       3 for num_clusters in list(K):
#       4     kmode = KModes(n_clusters=num_clusters, init = "random", n_init = 5, verbose=1)
# ----> 5     kmode.fit_predict(df_target_cluster)
#       6     cost.append(kmode.cost_)
#       7
#
# ~\anaconda3\lib\site-packages\kmodes\kmodes.py in fit_predict(self, X, y, **kwargs)
#     152         predict(X).
#     153         """
# --> 154         return self.fit(X, **kwargs).predict(X, **kwargs)
#     155
#     156     def predict(self, X, **kwargs):
#
# ~\anaconda3\lib\site-packages\kmodes\kmodes.py in fit(self, X, y, sample_weight, **kwargs)
#     132
#     133         self._enc_cluster_centroids, self._enc_map, self.labels_, self.cost_, \
# --> 134         self.n_iter_, self.epoch_costs_ = k_modes(
#     135             X,
# ...

# %%
kmode = KModes(n_clusters=2, init = "random", n_init = 5, verbose=1)
clusters = kmode.fit_predict(df_target_cluster)
clusters

# %%
df_cluster_result = df_target_cluster.copy()

# %%
df_cluster_result['cluster'] = clusters

# %%
df_cluster_result

# %%
df_cluster_result[df_cluster_result['cluster'] == 0]

# %%
df_cluster_result[df_cluster_result['cluster'] == 1]

# %%
df_target_cluster

# %%
# Out:
#   Cell In[1], line 1
#     df_cluster_result[df_cluster_result['cluster'] == 1]df_cluster_result[df_cluster_result['cluster'] == 2]
#                                                         ^
# SyntaxError: invalid syntax
